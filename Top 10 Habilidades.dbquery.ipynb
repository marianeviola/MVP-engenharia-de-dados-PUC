-- %%
SELECT
    T2.SKILL_NAME,
    COUNT(DISTINCT T1.ID) AS Total_Vagas_Exigindo_Habilidade
FROM jobs.gold.fato_demanda T1
JOIN jobs.gold.dim_habilidade T2
    ON T1.ID_HABILIDADE_HASH = T2.ID_HABILIDADE_HASH
GROUP BY 1
ORDER BY Total_Vagas_Exigindo_Habilidade DESC
LIMIT 10;
